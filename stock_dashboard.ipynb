# %%
import pandas as pd
import yfinance as yf
import datetime as dt
import plotly.graph_objects as go

# %%
n_years = 1
end_date = dt.datetime.now()
start_date = end_date - dt.timedelta(days=365*n_years)

ticker = ['PETR4.SA', 'WEGE3.SA', 'CEAB3.SA']

df = yf.download(tickers=ticker, start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
df = df.drop(columns=['Adj Close', 'Volume']).reset_index()

# %%
df.head()
# Out:
#         Date    Close                           High                        \
#              CEAB3.SA   PETR4.SA   WEGE3.SA CEAB3.SA   PETR4.SA   WEGE3.SA
# 0 2023-01-04     2.25  23.049999  37.400002     2.25  23.590000  37.689999
# 1 2023-01-05     2.31  23.879999  37.480000     2.34  24.040001  37.900002
# 2 2023-01-06     2.35  23.740000  38.029999     2.36  24.320000  38.270000
# 3 2023-01-09     2.36  23.870001  37.919998     2.39  24.000000  38.299999
# 4 2023-01-10     2.56  24.090000  37.549999     2.59  24.110001  37.910000
#
#        Low                           Open
#   CEAB3.SA   PETR4.SA   WEGE3.SA CEAB3.SA   PETR4.SA   WEGE3.SA
# 0     2.13  21.830000  36.660000     2.14  21.959999  37.330002
# 1     2.22  23.150000  37.259998     2.25  23.340000  37.590000
# 2     2.25  23.549999  37.299999     2.27  23.940001  37.490002
# 3     2.26  23.250000  37.220001     2.33  23.500000  38.000000
# 4     2.31  23.370001  37.080002     2.34  23.950001  37.520000

# %%
df['Date']
# Out:
# 0     2023-01-04
# 1     2023-01-05
# 2     2023-01-06
# 3     2023-01-09
# 4     2023-01-10
#          ...
# 244   2023-12-27
# 245   2023-12-28
# 246   2024-01-02
# 247   2024-01-03
# 248   2024-01-04
# Name: Date, Length: 249, dtype: datetime64[ns]

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                                     open=df['Open']['PETR4.SA'],
                                     high=df['High']['PETR4.SA'],
                                     low=df['Low']['PETR4.SA'],
                                     close=df['Close']['PETR4.SA'])])
fig.update_layout(height = 500,
                  width = 1000,
                  margin_b = 40,
                  margin_r = 40,
                  margin_t = 40,
                  margin_l = 40,
                  xaxis_rangeslider_visible=False)
fig.show()
